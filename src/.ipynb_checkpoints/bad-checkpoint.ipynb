# %% [markdown]
# # imports

# %%
# %load_ext autoreload
# %autoreload 2
packages = !conda list
len(packages),packages
# Out:
# (455,
#  ['# packages in environment at /Users/brucecottman/anaconda3:',
#   '#',
#   '# Name                    Version                   Build  Channel',
#   '_anaconda_depends         2019.10                  py37_0  ',
#   '_ipyw_jlab_nb_ext_conf    0.1.0                    py37_0  ',
#   'absl-py                   0.7.0                    pypi_0    pypi',
#   'alabaster                 0.7.12                   py37_0  ',
#   'altair                    4.0.0                    pypi_0    pypi',
#   'anaconda                  custom                   py37_1  ',
#   'anaconda-client           1.7.2                    py37_0  ',
#   'anaconda-navigator        1.9.6                    py37_0  ',
#   'anaconda-project          0.8.2                    py37_0  ',
#   'appdirs                   1.4.3                    pypi_0    pypi',
#   'appnope                   0.1.0                    py37_0  ',
#   'appscript                 1.0.1            py37h1de35cc_1  ',
#   'argh                      0.26.2                   pypi_0    pypi',
#   'argparse                  1.4.0                    pypi_0    pypi',
#   'arrow                     0.15.8                   pypi_0    pypi',
#   'asn1crypto                0.24.0                   py37_0  ',
#   'astor                     0.7.1                    pypi_0    pypi',
#   'astroid                   2.4.0                    pypi_0    pypi',
#   'astropy                   3.1              py37h1de35cc_0  ',
#   'atomicwrites              1.2.1                    py37_0  ',
#   'attrdict                  2.0.1                    pypi_0    pypi',
#   'attrs                     19.3.0                   pypi_0    pypi',
#   'babel                     2.6.0                    py37_0  ',
#   'backcall                  0.1.0                    py37_0  ',
#   'backports                 1.0                      py37_1  ',
#   'backports.os              0.1.1                    py37_0  ',
#   'backports.shutil_get_terminal_size 1.0.0                    py37_2  ',
#   'base58                    1.0.3                    pypi_0    pypi',
#   'beautifulsoup4            4.6.3                    py37_0  ',
#   'binaryornot               0.4.4                    pypi_0    pypi',
#   'bitarray                  0.8.3            py37h1de35cc_0  ',
#   'bkcharts                  0.2                      py37_0  ',
#   'black                     19.10b0                  pypi_0    pypi',
#   'blas                      1.0                         mkl  ',
#   'blaze                     0.11.3                   py37_0  ',
#   'bleach                    3.0.2                    py37_0  ',
#   'blinker                   1.4                      pypi_0    pypi',
#   'blosc                     1.14.4               hd9629dc_0  ',
#   'bokeh                     1.0.2                    py37_0  ',
#   'boto                      2.49.0                   py37_0  ',
#   'boto3                     1.14.60                  pypi_0    pypi',
#   'botocore                  1.17.60                  pypi_0    pypi',
#   'bottleneck                1.2.1            py37h1d22016_1  ',
#   'brotlipy                  0.7.0           py37h9ed2024_1003  ',
#   'bzip2                     1.0.6                h1de35cc_5  ',
#   'ca-certificates           2020.12.5            h033912b_0    conda-forge',
#   'catboost                  0.12.2                   pypi_0    pypi',
#   'category-encoders         1.3.0                    pypi_0    pypi',
#   'certifi                   2020.12.5        py37hf985489_1    conda-forge',
#   'cffi                      1.14.0           py37hb5b8e2f_0  ',
#   'chardet                   4.0.0           py37hecd8cb5_1003  ',
#   'click                     6.2                      pypi_0    pypi',
#   'click-default-group       1.2.2                    pypi_0    pypi',
#   'cloudpickle               0.6.1                    py37_0  ',
#   'clyent                    1.2.2                    py37_1  ',
#   'cmake                     3.18.2.post1             pypi_0    pypi',
#   'colorama                  0.4.3                    pypi_0    pypi',
#   'colorlog                  4.1.0                    pypi_0    pypi',
#   'conda                     4.9.2            py37hf985489_0    conda-forge',
#   'conda-build               3.17.6                   py37_0  ',
#   'conda-env                 2.6.0                         1  ',
#   'conda-package-handling    1.7.2            py37h22f3db7_0  ',
#   'conda-verify              3.1.1                    py37_0  ',
#   'contextlib2               0.5.5                    py37_0  ',
#   'cookiecutter              1.7.2                    pypi_0    pypi',
#   'coverage                  4.5.2                    pypi_0    pypi',
#   'cryptography              3.4.7            py37h2fd3fbb_0  ',
#   'curl                      7.63.0            ha441bb4_1000  ',
#   'cvxpy                     1.0.21                   pypi_0    pypi',
#   'cycler                    0.10.0                   py37_0  ',
#   'cymem                     2.0.2                    pypi_0    pypi',
#   'cython                    0.29.2           py37h0a44026_0  ',
#   'cytoolz                   0.9.0.1          py37h1de35cc_1  ',
#   'dask                      1.0.0                    py37_0  ',
#   'dask-core                 1.0.0                    py37_0  ',
#   'datareader                0.0.9                    pypi_0    pypi',
#   'datashape                 0.5.4                    py37_1  ',
#   'dbus                      1.13.2               h760590f_1  ',
#   'decorator                 4.4.2                    pypi_0    pypi',
#   'defusedxml                0.5.0                    py37_1  ',
#   'diagrams                  0.17.0                   pypi_0    pypi',
#   'dill                      0.2.9                    pypi_0    pypi',
#   'distributed               1.25.1                   py37_0  ',
#   'docker                    4.2.0                    pypi_0    pypi',
#   'docutils                  0.14                     py37_0  ',
#   'ecos                      2.0.7.post1              pypi_0    pypi',
#   'entrypoints               0.3                      pypi_0    pypi',
#   'enum-compat               0.0.3                    pypi_0    pypi',
#   'enum34                    1.1.6                    pypi_0    pypi',
#   'et_xmlfile                1.0.1                    py37_0  ',
#   'expat                     2.2.6                h0a44026_0  ',
#   'fancyimpute               0.4.3                    pypi_0    pypi',
#   'fastai                    1.0.45                   pypi_0    pypi',
#   'fastcache                 1.0.2            py37h1de35cc_2  ',
#   'fastcore                  1.3.20                   pypi_0    pypi',
#   'fasteners                 0.15                     pypi_0    pypi',
#   'fastprogress              0.1.19                   pypi_0    pypi',
#   'fastrelease               0.1.11                   pypi_0    pypi',
#   'filelock                  3.0.10                   py37_0  ',
#   'flake8                    3.7.9                    pypi_0    pypi',
#   'flake8-polyfill           1.0.2                    pypi_0    pypi',
#   'flask                     1.0.2                    py37_1  ',
#   'flask-cors                3.0.7                    py37_0  ',
#   'flask-wtf                 0.14.2                   pypi_0    pypi',
#   'fonttools                 4.33.3                   pypi_0    pypi',
#   'fred                      3.1                      pypi_0    pypi',
#   'freetype                  2.9.1                hb4e5f40_0  ',
#   'fsspec                    0.8.7              pyhd8ed1ab_0    conda-forge',
#   'future                    0.18.2                   pypi_0    pypi',
#   'gast                      0.2.2                    pypi_0    pypi',
#   'gcloud                    0.18.3                   pypi_0    pypi',
#   'get_terminal_size         1.0.0                h7520d66_0  ',
#   'gettext                   0.19.8.1             h15daf44_3  ',
#   'gevent                    1.3.7            py37h1de35cc_1  ',
#   'gfm                       0.0.3                    pypi_0    pypi',
#   'ghapi                     0.1.17                   pypi_0    pypi',
#   'gitdb2                    2.0.6                    pypi_0    pypi',
#   'gitpython                 2.1.15                   pypi_0    pypi',
#   'glib                      2.56.2               hd9629dc_0  ',
#   'glob2                     0.6                      py37_1  ',
#   'gmp                       6.1.2                hb37e062_1  ',
#   'gmpy2                     2.0.8            py37h6ef4df4_2  ',
#   'googleapis-common-protos  1.53.0                   pypi_0    pypi',
#   'greenlet                  0.4.15           py37h1de35cc_0  ',
#   'grpcio                    1.18.0                   pypi_0    pypi',
#   'h5py                      2.8.0            py37h878fce3_3  ',
#   'hdf5                      1.10.2               hfa1e0ec_1  ',
#   'heapdict                  1.0.0                    py37_2  ',
#   'html2text                 2015.11.4                pypi_0    pypi',
#   'html5lib                  1.0.1                    py37_0  ',
#   'httplib2                  0.19.1                   pypi_0    pypi',
#   'icu                       58.2                 h4b95b61_1  ',
#   'idna                      2.10               pyhd3eb1b0_0  ',
#   'imagehash                 4.2.1                    pypi_0    pypi',
#   'imageio                   2.4.1                    py37_0  ',
#   'imagesize                 1.1.0                    py37_0  ',
#   'imbalanced-learn          0.5.0                    pypi_0    pypi',
#   'imblearn                  0.0                      pypi_0    pypi',
#   'importlib-metadata        1.5.0                    pypi_0    pypi',
#   'importlib_metadata        0.6                      py37_0  ',
#   'intel-openmp              2019.1                      144  ',
#   'ipykernel                 5.1.0            py37h39e3cac_0  ',
#   'ipython                   7.2.0            py37h39e3cac_0  ',
#   'ipython-genutils          0.2.0                    pypi_0    pypi',
#   'ipython_genutils          0.2.0                    py37_0  ',
#   'ipywidgets                7.4.2                    py37_0  ',
#   'isort                     4.3.21                   pypi_0    pypi',
#   'isoweek                   1.3.3                    pypi_0    pypi',
#   'itsdangerous              1.1.0                    py37_0  ',
#   'jbig                      2.1                  h4d881f8_0  ',
#   'jdcal                     1.4                      py37_0  ',
#   'jedi                      0.13.2                   py37_0  ',
#   'jinja2                    2.11.2                   pypi_0    pypi',
#   'jinja2-time               0.2.0                    pypi_0    pypi',
#   'jmespath                  0.9.4                    pypi_0    pypi',
#   'joblib                    1.1.0                    pypi_0    pypi',
#   'jp-proxy-widget           1.0.9                    pypi_0    pypi',
#   'jpeg                      9b                   he5867d9_2  ',
#   'json5                     0.9.5              pyh9f0ad1d_0    conda-forge',
#   'jsonschema                3.2.0                    pypi_0    pypi',
#   'jupyter                   1.0.0                    py37_7  ',
#   'jupyter-contrib-core      0.3.3                    pypi_0    pypi',
#   'jupyter-contrib-nbextensions 0.5.1                    pypi_0    pypi',
#   'jupyter-core              4.6.3                    pypi_0    pypi',
#   'jupyter-highlight-selected-word 0.2.0                    pypi_0    pypi',
#   'jupyter-latex-envs        1.4.6                    pypi_0    pypi',
#   'jupyter-nbextensions-configurator 0.4.1                    pypi_0    pypi',
#   'jupyter-ui-poll           0.1.2                    pypi_0    pypi',
#   'jupyter_client            5.2.4                    py37_0  ',
#   'jupyter_console           6.0.0                    py37_0  ',
#   'jupyter_core              4.4.0                    py37_0  ',
#   'jupyterlab                0.35.3                   py37_0  ',
#   'jupyterlab_server         0.2.0                    py37_0  ',
#   'keras                     2.2.4                    pypi_0    pypi',
#   'keras-applications        1.0.7                    pypi_0    pypi',
#   'keras-preprocessing       1.0.9                    pypi_0    pypi',
#   'keyring                   17.0.0                   py37_0  ',
#   'kiwisolver                1.0.1            py37h0a44026_0  ',
#   'knnimpute                 0.1.0                    pypi_0    pypi',
#   'krb5                      1.16.1               hddcf347_7  ',
#   'lazy-object-proxy         1.4.3                    pypi_0    pypi',
#   'libarchive                3.3.3                h786848e_5  ',
#   'libcurl                   7.63.0            h051b688_1000  ',
#   'libcxx                    4.0.1                hcfea43d_1  ',
#   'libcxxabi                 4.0.1                hcfea43d_1  ',
#   'libedit                   3.1.20170329         hb402a30_2  ',
#   'libffi                    3.2.1                h475c297_4  ',
#   'libgfortran               3.0.1                h93005f0_2  ',
#   'libiconv                  1.15                 hdd342a3_7  ',
#   'liblief                   0.9.0                h2a1bed3_0  ',
#   'libpng                    1.6.35               ha441bb4_0  ',
#   'libsodium                 1.0.16               h3efe00b_0  ',
#   'libssh2                   1.8.0                ha12b0ac_4  ',
#   'libtiff                   4.0.9                hcb84e12_2  ',
#   'libxml2                   2.9.8                hab757c2_1  ',
#   'libxslt                   1.1.32               hb819dd2_0  ',
#   'lightgbm                  2.2.3                    pypi_0    pypi',
#   'llvm-openmp               11.1.0               hda6cdc1_0    conda-forge',
#   'llvmlite                  0.26.0           py37h8c7ce04_0  ',
#   'locket                    0.2.0                    py37_1  ',
#   'loguru                    0.5.3                    pypi_0    pypi',
#   'lxml                      4.2.5            py37hef8c89e_0  ',
#   'lz4-c                     1.8.1.2              h1de35cc_0  ',
#   'lzo                       2.10                 h362108e_2  ',
#   'mando                     0.6.4                    pypi_0    pypi',
#   'markdown                  2.6.5                    pypi_0    pypi',
#   'markupsafe                2.1.1                    pypi_0    pypi',
#   'matplotlib                3.5.2                    pypi_0    pypi',
#   'mccabe                    0.6.1                    pypi_0    pypi',
#   'mistune                   0.8.4            py37h1de35cc_0  ',
#   'mkl                       2019.1                      144  ',
#   'mkl-service               1.1.2            py37hfbe908c_5  ',
#   'mkl_fft                   1.0.6            py37h27c97d8_0  ',
#   'mkl_random                1.0.2            py37h27c97d8_0  ',
#   'mock                      2.0.0                    pypi_0    pypi',
#   'monotonic                 1.5                      pypi_0    pypi',
#   'more-itertools            4.3.0                    py37_0  ',
#   'mpc                       1.1.0                h6ef4df4_1  ',
#   'mpfr                      4.0.1                h3018a27_3  ',
#   'mpmath                    1.1.0                    py37_0  ',
#   'msgpack-numpy             0.4.3.2                  pypi_0    pypi',
#   'msgpack-python            0.5.6            py37h04f5b5a_1  ',
#   'multimethod               1.8                      pypi_0    pypi',
#   'multipledispatch          0.6.0                    py37_0  ',
#   'multiprocess              0.70.7                   pypi_0    pypi',
#   'murmurhash                1.0.1                    pypi_0    pypi',
#   'navigator-updater         0.2.1                    py37_0  ',
#   'nbconvert                 5.4.1                    pypi_0    pypi',
#   'nbdev                     1.1.14                   pypi_0    pypi',
#   'nbformat                  4.4.0                    py37_0  ',
#   'nbsphinx                  0.4.2                    pypi_0    pypi',
#   'ncurses                   6.1                  h0a44026_1  ',
#   'networkx                  2.6.3                    pypi_0    pypi',
#   'nibabel                   3.0.1                    pypi_0    pypi',
#   'nilearn                   0.5.0                    pypi_0    pypi',
#   'ninja                     1.8.2            py37h04f5b5a_1  ',
#   'nltk                      3.4                      py37_1  ',
#   'nose                      1.3.7                    py37_2  ',
#   'notebook                  5.7.10           py37hc8dfbb8_0    conda-forge',
#   'np-utils                  0.5.10.0                 pypi_0    pypi',
#   'numba                     0.41.0           py37h6440ff4_0  ',
#   'numexpr                   2.6.8            py37h7413580_0  ',
#   'numpy                     1.21.6                   pypi_0    pypi',
#   'numpydoc                  0.8.0                    py37_0  ',
#   'nvidia-ml-py3             7.352.0                  pypi_0    pypi',
#   'oauth2client              4.1.3                    pypi_0    pypi',
#   'odo                       0.5.1                    py37_0  ',
#   'olefile                   0.46                     py37_0  ',
#   'opencv-python             4.5.5.64                 pypi_0    pypi',
#   'openpyxl                  2.5.12                   py37_0  ',
#   'openssl                   1.1.1k               h0d85af4_0    conda-forge',
#   'opt-einsum                3.0.1                    pypi_0    pypi',
#   'osqp                      0.5.0                    pypi_0    pypi',
#   'packaging                 21.3                     pypi_0    pypi',
#   'pandas                    0.25.3                   pypi_0    pypi',
#   'pandas-datareader         0.10.0                   pypi_0    pypi',
#   'pandas-flavor             0.2.0                    pypi_0    pypi',
#   'pandas-summary            0.0.6                    pypi_0    pypi',
#   'pandoc                    1.19.2.1             ha5e8f32_1  ',
#   'pandocfilters             1.4.2                    py37_1  ',
#   'parso                     0.3.1                    py37_0  ',
#   'partd                     0.3.9                    py37_0  ',
#   'paso                      0.2.9                    pypi_0    pypi',
#   'path.py                   11.5.0                   py37_0  ',
#   'pathlib2                  2.3.3                    py37_0  ',
#   'pathspec                  0.8.0                    pypi_0    pypi',
#   'pathtools                 0.1.2                    pypi_0    pypi',
#   'patsy                     0.5.1                    py37_0  ',
#   'pbr                       5.1.2                    pypi_0    pypi',
#   'pcre                      8.42                 h378b8a2_0  ',
#   'pep8                      1.7.1                    py37_0  ',
#   'pexpect                   4.6.0                    py37_0  ',
#   'pi                        0.1.2                    pypi_0    pypi',
#   'pickleshare               0.7.5                    py37_0  ',
#   'pillow                    6.2.1                    pypi_0    pypi',
#   'pip                       20.2.3                   pypi_0    pypi',
#   'pkginfo                   1.4.2                    py37_1  ',
#   'plac                      0.9.6                    pypi_0    pypi',
#   'plotly                    4.5.4                    pypi_0    pypi',
#   'pluggy                    0.8.0                    py37_0  ',
#   'ply                       3.11                     py37_0  ',
#   'poyo                      0.5.0                    pypi_0    pypi',
#   'preshed                   2.0.1                    pypi_0    pypi',
#   'prettytable               0.7.2                    pypi_0    pypi',
#   'probscale                 0.2.3                    pypi_0    pypi',
#   'profiling                 0.1.3                    pypi_0    pypi',
#   'progress                  1.4                      pypi_0    pypi',
#   'progressbar2              3.50.0                   pypi_0    pypi',
#   'prometheus_client         0.5.0                    py37_0  ',
#   'prompt_toolkit            2.0.7                    py37_0  ',
#   'protobuf                  3.16.0rc1                pypi_0    pypi',
#   'psutil                    5.4.8            py37h1de35cc_0  ',
#   'ptyprocess                0.6.0                    py37_0  ',
#   'py                        1.7.0                    py37_0  ',
#   'py-lief                   0.9.0            py37hd4eaf27_0  ',
#   'pyaml                     19.12.0                  pypi_0    pypi',
#   'pyarrow                   0.13.0                   pypi_0    pypi',
#   'pyasn1                    0.4.8                    pypi_0    pypi',
#   'pyasn1-modules            0.2.8                    pypi_0    pypi',
#   'pycodestyle               2.5.0                    pypi_0    pypi',
#   'pycosat                   0.6.3            py37h9ed2024_0  ',
#   'pycparser                 2.20                       py_2  ',
#   'pycrypto                  2.6.1            py37h1de35cc_9  ',
#   'pycurl                    7.43.0.2         py37ha12b0ac_0  ',
#   'pydot-ng                  2.0.0                    pypi_0    pypi',
#   'pyflakes                  2.1.1                    pypi_0    pypi',
#   'pygments                  2.3.1                    py37_0  ',
#   'pylint                    2.5.0                    pypi_0    pypi',
#   'pymodm                    0.4.1                    pypi_0    pypi',
#   'pymongo                   3.10.1                   pypi_0    pypi',
#   'pyodbc                    4.0.25           py37h0a44026_0  ',
#   'pyopenssl                 20.0.1             pyhd3eb1b0_1  ',
#   'pyparsing                 2.4.7                    pypi_0    pypi',
#   'pyqt                      5.9.2            py37h655552a_2  ',
#   'pyqt5                     5.9.2                    pypi_0    pypi',
#   'pyrsistent                0.15.7                   pypi_0    pypi',
#   'pyrss2gen                 1.1                      pypi_0    pypi',
#   'pysocks                   1.7.1            py37hecd8cb5_0  ',
#   'pytables                  3.4.4            py37h13cba08_0  ',
#   'pytest                    4.0.2                    py37_0  ',
#   'pytest-arraydiff          0.3              py37h39e3cac_0  ',
#   'pytest-astropy            0.5.0                    py37_0  ',
#   'pytest-doctestplus        0.2.0                    py37_0  ',
#   'pytest-openfiles          0.3.1                    py37_0  ',
#   'pytest-remotedata         0.3.1                    py37_0  ',
#   'python                    3.7.2                haf84260_0  ',
#   'python-dateutil           2.7.5                    py37_0  ',
#   'python-graphviz           0.13.2                   pypi_0    pypi',
#   'python-libarchive-c       2.8                      py37_6  ',
#   'python-slugify            4.0.1                    pypi_0    pypi',
#   'python-utils              2.4.0                    pypi_0    pypi',
#   'python.app                2                        py37_9  ',
#   'python_abi                3.7                     1_cp37m    conda-forge',
#   'pytorch                   1.0.1                   py3.7_2    pytorch',
#   'pytz                      2018.7                   py37_0  ',
#   'pywavelets                1.0.1            py37h1d22016_0  ',
#   'pyyaml                    3.13             py37h1de35cc_0  ',
#   'pyzmq                     17.1.2           py37h1de35cc_0  ',
#   'qt                        5.9.7                h468cd18_1  ',
#   'qtawesome                 0.5.3                    py37_0  ',
#   'qtconsole                 4.4.3                    py37_0  ',
#   'qtpy                      1.5.2                    py37_0  ',
#   'radon                     4.0.0                    pypi_0    pypi',
#   'readline                  7.0                  h1de35cc_5  ',
#   'regex                     2018.1.10                pypi_0    pypi',
#   'requests                  2.24.0                   pypi_0    pypi',
#   'retrying                  1.3.3                    pypi_0    pypi',
#   'ripgrep                   12.1.1               haf1e3a3_1    conda-forge',
#   'rope                      0.11.0                   py37_0  ',
#   'rsa                       4.7.2                    pypi_0    pypi',
#   'ruamel_yaml               0.15.87          py37h1de35cc_0  ',
#   's3fs                      0.2.1                    pypi_0    pypi',
#   's3transfer                0.3.3                    pypi_0    pypi',
#   'scikit-image              0.14.1           py37h0a44026_0  ',
#   'scikit-learn              0.22.2                   pypi_0    pypi',
#   'scikit-optimize           0.7.4                    pypi_0    pypi',
#   'scipy                     1.7.3                    pypi_0    pypi',
#   'scs                       2.1.0                    pypi_0    pypi',
#   'seaborn                   0.11.2                   pypi_0    pypi',
#   'send2trash                1.5.0                    py37_0  ',
#   'setuptools                41.2.0                   pypi_0    pypi',
#   'simplegeneric             0.8.1                    py37_2  ',
#   'singledispatch            3.4.0.3                  py37_0  ',
#   'sip                       4.19.8                   pypi_0    pypi',
#   'six                       1.14.0                   pypi_0    pypi',
#   'smmap                     3.0.1                    pypi_0    pypi',
#   'smmap2                    3.0.1                    pypi_0    pypi',
#   'snakeviz                  2.1.0                    pypi_0    pypi',
#   'snappy                    1.1.7                he62c110_3  ',
#   'snowballstemmer           1.2.1                    py37_0  ',
#   'sortedcollections         1.0.1                    py37_0  ',
#   'sortedcontainers          2.1.0                    py37_0  ',
#   'soupsieve                 2.0.1                      py_1    conda-forge',
#   'spacy                     2.0.18                   pypi_0    pypi',
#   'sphinx                    1.8.2                    py37_0  ',
#   'sphinx-automodapi         0.10                     pypi_0    pypi',
#   'sphinx-gallery            0.2.0                    pypi_0    pypi',
#   'sphinxcontrib             1.0                      py37_1  ',
#   'sphinxcontrib-applehelp   1.0.2                      py_0    conda-forge',
#   'sphinxcontrib-devhelp     1.0.2                      py_0    conda-forge',
#   'sphinxcontrib-htmlhelp    1.0.3                      py_0    conda-forge',
#   'sphinxcontrib-jsmath      1.0.1                      py_0    conda-forge',
#   'sphinxcontrib-qthelp      1.0.3                      py_0    conda-forge',
#   'sphinxcontrib-serializinghtml 1.1.4                      py_0    conda-forge',
#   'sphinxcontrib-websupport  1.1.0                    py37_1  ',
#   'spyder                    3.3.2                    py37_0  ',
#   'spyder-kernels            0.3.0                    py37_0  ',
#   'sqlalchemy                1.2.15           py37h1de35cc_0  ',
#   'sqlite                    3.26.0               ha441bb4_0  ',
#   'statsmodels               0.9.0            py37h1d22016_0  ',
#   'streamlit                 0.51.0                   pypi_0    pypi',
#   'sympy                     1.3                      py37_0  ',
#   'symspellcpppy             0.0.8                    pypi_0    pypi',
#   'symspellpy                6.5.2                    pypi_0    pypi',
#   'tabulate                  0.8.6                    pypi_0    pypi',
#   'tangled-up-in-unicode     0.2.0                    pypi_0    pypi',
#   'tb-nightly                1.15.0a20190806          pypi_0    pypi',
#   'tbb                       2019.8               h770b8ee_0    conda-forge',
#   'tblib                     1.3.2                    py37_0  ',
#   'tensorboard               1.12.2                   pypi_0    pypi',
#   'tensorflow                1.13.0rc2                pypi_0    pypi',
#   'tensorflow-estimator      1.13.0rc0                pypi_0    pypi',
#   'termcolor                 1.1.0                    pypi_0    pypi',
#   'terminado                 0.8.1                    py37_1  ',
#   'testpath                  0.4.2                    py37_0  ',
#   'text-unidecode            1.3                      pypi_0    pypi',
#   'thinc                     6.12.1                   pypi_0    pypi',
#   'tk                        8.6.8                ha441bb4_0  ',
#   'toml                      0.10.0                   pypi_0    pypi',
#   'toolz                     0.9.0                    py37_0  ',
#   'torchvision               0.2.1                      py_2    pytorch',
#   'tornado                   5.1.1            py37h1de35cc_0  ',
#   'tqdm                      4.31.1                   pypi_0    pypi',
#   'traitlets                 4.3.3                    pypi_0    pypi',
#   'typed-ast                 1.4.1                    pypi_0    pypi',
#   'typing                    3.6.6                    pypi_0    pypi',
#   'typing-extensions         4.2.0                    pypi_0    pypi',
#   'tzlocal                   2.0.0                    pypi_0    pypi',
#   'ujson                     1.35                     pypi_0    pypi',
#   'unicodecsv                0.14.1                   py37_0  ',
#   'unixodbc                  2.3.7                h1de35cc_0  ',
#   'urllib3                   1.26.4             pyhd3eb1b0_0  ',
#   'urwid                     2.1.2                    pypi_0    pypi',
#   'validators                0.14.1                   pypi_0    pypi',
#   'valuedispatch             0.0.1                    pypi_0    pypi',
#   'visions                   0.7.4                    pypi_0    pypi',
#   'watchdog                  0.8.3                    pypi_0    pypi',
#   'wcwidth                   0.1.7                    py37_0  ',
#   'webencodings              0.5.1                    py37_1  ',
#   'websocket-client          0.57.0                   pypi_0    pypi',
#   'werkzeug                  0.14.1                   py37_0  ',
#   'wheel                     0.33.1                   pypi_0    pypi',
#   'widgetsnbextension        3.4.2                    py37_0  ',
#   'wily                      1.16.0                   pypi_0    pypi',
#   'wrapt                     1.12.1                   pypi_0    pypi',
#   'wtforms                   2.2.1                    pypi_0    pypi',
#   'wurlitzer                 1.0.2                    py37_0  ',
#   'xarray                    0.14.0                   pypi_0    pypi',
#   'xeus                      0.19.2               h770b8ee_0    conda-forge',
#   'xeus-python               0.2.2            py37h770b8ee_2    conda-forge',
#   'xgboost                   0.90                     pypi_0    pypi',
#   'xlrd                      1.2.0                    py37_0  ',
#   'xlsxwriter                1.1.2                    py37_0  ',
#   'xlwings                   0.15.1                   py37_0  ',
#   'xlwt                      1.3.0                    py37_0  ',
#   'xz                        5.2.4                h1de35cc_4  ',
#   'yaml                      0.1.7                hc338f04_2  ',
#   'zeromq                    4.2.5                h0a44026_1  ',
#   'zict                      0.1.3                    py37_0  ',
#   'zipp                      3.1.0                    pypi_0    pypi',
#   'zlib                      1.2.11               h1de35cc_3  ',
#   'zstd                      1.3.7                h5bba6e5_0  '])

# %% [markdown]
# ## common imports

# %%
from __future__ import print_function
import matplotlib
import matplotlib.dates as mdates
import matplotlib.ticker as mtick
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import sys, os
import io
from typing import Dict, Pattern

import seaborn as sns; sns.set()  # for plot styling
#set font size of labels on matplotlib plots
plt.rc('font', size=16)

#set style of plots
sns.set_style('white')

#define a custom palette
PALLET = ['#40111D', '#DCD5E4', '#E7CC74'
                 ,'#39C8C6', '#AC5583', '#D3500C'
                 ,'#FFB139', '#98ADA7', '#AD989E'
                 ,'#708090','#6C8570','#3E534D'

                 ,'#0B8FD3','#0B47D3','#96D30B'                 
                 ,'#630C3A','#F1D0AF','#64788B'                 
                 ,'#8B7764','#7A3C5D','#77648B'
                 ,'#eaff39','#39ff4e','#4e39ff'
                 ,'#ff4e39','#87ff39','#ff3987', ]
N_PALLET = len(PALLET)
sns.set_palette(PALLET)
sns.palplot(PALLET)

# %% [markdown]
# ## finance imports

# %%
#!pip install pandas_datareader #if not already installed 
from pandas import to_datetime, DataFrame
from statistics import stdev
from pandas_datareader.data import DataReader
from math import inf
from pandas_datareader.data import DataReader
import copy
import plotly.express as px

# %% [markdown]
# ## local imports

# %%
# add if you want to add google driveAssertionError
old__file__ = !pwd
__file__ =  old__file__  #!cd ../../NLP ;pwd
#__file__ = !pwd
#__file__ = '/gdrive/My Drive'

sys.path.append(__file__)
print(sys.path)
os.chdir(old__file__[0])
# !pwd
__file__
# Out:
# ['/Users/brucecottman/Documents/PROJECTS/FinMrkt/src', '/usr/local/Cellar/apache-spark/2.0.1/libexec/python', '/Users/brucecottman/Documents/PROJECTS/FinMrkt/src/$', '/Library/Frameworks/Python.framework/Versions/3.7/lib/python37.zip', '/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7', '/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/lib-dynload', '', '/Users/brucecottman/Library/Python/3.7/lib/python/site-packages', '/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages', '/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/extensions', '/Users/brucecottman/.ipython', ['/Users/brucecottman/Documents/PROJECTS/FinMrkt/src']]
# /Users/brucecottman/Documents/PROJECTS/FinMrkt/src
# ['/Users/brucecottman/Documents/PROJECTS/FinMrkt/src']

# %% [markdown]
# ## import from  /PROJECTS/FinMrkt/src/base

# %%
from base import FutureValue_, nppy_
from base import return_fit, price_std,  price_std_f
from base import p_or_r_std, p_or_r_std_f, ticket_read
from base import register_DataFrame_method

# %% [markdown]
# #  functions

# %% [markdown]
# ## function  Fed_indexes_corr

# %%
def Fed_indexes_corr(Primary_df, Secondary_df, 
                          condition = [-inf, inf],
                          shift__=0, 
                          bottom_year = '1985/1/01',
                          top_year = '1/1/2060'):
                          
    plt.figure(figsize=(12, 8))
    Secondary_df['index']= Secondary_df.index
    Primary_df['index']= Primary_df.index
    # make sure on a loop
    Primary_df[Secondary_df.columns[0]] = 0
    
    Secondary_df = Secondary_df[Primary_df['index'] > bottom_year]
    Primary_df = Primary_df[Primary_df['index'] > bottom_year]
    Secondary_df = Secondary_df[Primary_df['index' ] < top_year]   
    Primary_df = Primary_df[Primary_df['index' ] < top_year]
# condition
    Secondary_df = Secondary_df[Primary_df[Primary_df.columns[0]] > condition[0]]
    Primary_df = Primary_df[Primary_df[Primary_df.columns[0]] > condition[0]]
    Primary_df = Primary_df.shift(shift__)
    
#    1st plot
    ax = sns.lineplot(x='index', y =  Primary_df.columns[0],
                      color='red', linewidth=2.5, data=Primary_df)
    ax.yaxis.set_major_formatter(mtick.PercentFormatter())
# recession bars
    Recessions_plot(ax, bottom_year, top_year)
# 2nd subplot
    ax2 = ax.twinx()
    sns.lineplot(x='index', y=Secondary_df.columns[0], 
                 data=Secondary_df, color='black',
                 linewidth=2.5, ax=ax2)
    if Secondary_df.iloc[0,0] < 99 : ax2.yaxis.set_major_formatter(mtick.PercentFormatter())
    plt.show()
#heatmap
    Primary_df[Secondary_df.columns[0]] = Secondary_df[Secondary_df.columns[0]]
    hm = Primary_df.corr()
    sns.heatmap(hm, annot=True)
    plt.show()
    return hm

# %% [markdown]
# # read and plot ticker data

# %% [markdown]
# ## plot Recession bars 1

# %%
def Recessions_plot(ax, start_date, end_date):
    ticker = 'USREC'
    rd_type = 'fred'
    Recession_df = DataReader(ticker, rd_type, 
                            start = start_date, end = end_date) 

    Recession_df['index']= Recession_df.index
    threshold = 0
    ax.fill_between(Recession_df['index'], 0, 1, where=Recession_df[Recession_df.columns[0]] > threshold,
                    color='green', alpha=0.5, transform=ax.get_xaxis_transform())
    return(1)

# %% [markdown]
# ## plot Fed_indexes_corr

# %%
def Fed_indexes_corr(Primary_df, Secondary_df, 
                          condition = [-inf, inf],
                          shift__=0, 
                          bottom_year = '1/1/1960',
                          top_year = '1/1/2060'):
                          
    plt.figure(figsize=(12, 8))
    Secondary_df['index']= Secondary_df.index
    Primary_df['index']= Primary_df.index
    # make sure on a loop
    Primary_df[Secondary_df.columns[0]] = 0
    
    Secondary_df = Secondary_df[Primary_df['index'] > bottom_year]
    Primary_df = Primary_df[Primary_df['index'] > bottom_year]
    Secondary_df = Secondary_df[Primary_df['index' ] < top_year]   
    Primary_df = Primary_df[Primary_df['index' ] < top_year]
# condition
    Secondary_df = Secondary_df[Primary_df[Primary_df.columns[0]] > condition[0]]
    Primary_df = Primary_df[Primary_df[Primary_df.columns[0]] > condition[0]]
    Primary_df = Primary_df.shift(shift__)
    
#    1st plot
    ax = sns.lineplot(x='index', y =  Primary_df.columns[0],
                      color='red', linewidth=2.5, data=Primary_df)
    ax.yaxis.set_major_formatter(mtick.PercentFormatter())
# recession bars
    Recessions_plot(ax, bottom_year, top_year)
# 2nd subplot
    ax2 = ax.twinx()
    sns.lineplot(x='index', y=Secondary_df.columns[0], 
                 data=Secondary_df, color='black',
                 linewidth=2.5, ax=ax2)
    if Secondary_df.iloc[0,0] < 99 : ax2.yaxis.set_major_formatter(mtick.PercentFormatter())
    plt.show()
#heatmap
    Primary_df[Secondary_df.columns[0]] = Secondary_df[Secondary_df.columns[0]]
    hm = Primary_df.corr()
    sns.heatmap(hm, annot=True)
    plt.show()
    return hm

# %% [markdown]
# ## plot Recession bars 2

# %%
def plotbars_df(ax, ticker_df, fx_size=15, fy_size=8, color_ = 'green', threshold = -inf):
    plt.figure(figsize=(fx_size, fy_size))
    ticker_df['index']= ticker_df.index
    ax = sns.lineplot(x='index', y=ticker_df.columns[0], data=ticker_df,color="black", linewidth=2.5)


    ax.fill_between(ticker_df['index'], 0, 1, where=ticker_df[ticker_df.columns[0]] > threshold,
                    color=color_, alpha=0.5, transform=ax.get_xaxis_transform())

# %% [markdown]
# ## plot ticker_data

# %%
def plot_ticker_data(ticker_df, fx_size=15, fy_size=8, color_ = 'black', 
                     plot_rec=True,  
                     start_date = '1985/1/01', end_date = '2022/07/30' ):
    plt.figure(figsize=(fx_size, fy_size))

    sns.set_theme(style="whitegrid")
    ax=sns.lineplot(data=ticker_df, color = color_, linewidth=2.5)
    Recessions_plot(ax, start_date, end_date)
    return(ticker_df)

# %% [markdown]
# ## correlation

# %%
def index_correlation(Primary_df,Secondary_df, ):
#    Primary_df= Primary_df[Primary_df.columns[0]]
    Primary_df.index = Primary_df.index.to_period('M').to_timestamp('M') # monthend
    Secondary_df.index = Secondary_df.index.to_period('M').to_timestamp('M') # monthend
#    Primary_df[Secondary_df.columns[0]] = Secondary_df[Secondary_df.columns[0]]
    Primary_df = Primary_df.merge(Secondary_df, left_on='DATE', right_index=True).reset_index()
    hm = Primary_df.corr()
    sns.heatmap(hm, annot=True)
    plt.show()
    return hm, Primary_df,Secondary_df

# %% [markdown]
# ## read ticker

# %%
def read_ticker_data(rd_type = 'fred', ticker ='fedfunds',
                   fx_size=15, fy_size=8, color_ = 'black',
                   start_date = '1985/1/01', end_date = '2022/07/30'):

    ticker_df = DataReader(ticker, rd_type, 
                           start = start_date, end = end_date)
    return(ticker_df)

# %% [markdown]
# ## groupby 12-month

# %%
def groupby_month(data_df):
    data_c_df =data_df.groupby(pd.Grouper(freq='M')).count()
    data_df = data_df.groupby(pd.Grouper(freq='M')).sum()/data_c_df
    return(data_df, data_c_df)

# %% [markdown]
# ## rolling  12-month

# %%
def rolling_12_month(data_df):
    window = 12
    center_=False
    axis_ = 0
    closed_ = 'neither'
    data_df[data_df.columns[0]] = data_df[data_df.columns[0]].rolling(window, center=center_,  axis=axis_, closed=closed_).sum()/window
    return(data_df)

# %%
def read_FED_Rate(start_date = '1985/1/01',
                    end_date = '2022/07/30'):
    FED_Rate_df = read_ticker_data() #defaults are FRED CPI
    return(FED_Rate_df)

# %%
def read_CPI(start_date = '1985/1/01',
                end_date = '2022/07/30'):
    CPI_df = read_ticker_data(rd_type = 'fred', ticker ='MEDCPIM158SFRBCLE')
    return(CPI_df)

# %% [markdown]
# ## retrieve Recession data

# %%
def read_Recession(start_date = '1985/1/01',
                    end_date = '2022/07/30'):
    Recsession_df = read_ticker_data(rd_type = 'fred', ticker ='USREC')
    return(Recsession_df)

# %% [markdown]
# ## retrieve Fed rate

# %%
FEDFUNDSRate_df=read_FED_Rate()
plot_ticker_data(FEDFUNDSRate_df, fx_size=15, fy_size=8, color_ = 'black')
FEDFUNDSRate_df.describe(), FEDFUNDSRate_df.head(), FEDFUNDSRate_df.tail(n=7)
# Out:
# (         fedfunds
#  count  451.000000
#  mean     3.360554
#  std      2.814692
#  min      0.050000
#  25%      0.370000
#  50%      3.030000
#  75%      5.520000
#  max      9.850000,
#              fedfunds
#  DATE
#  1985-01-01      8.35
#  1985-02-01      8.50
#  1985-03-01      8.58
#  1985-04-01      8.27
#  1985-05-01      7.97,
#              fedfunds
#  DATE
#  2022-01-01      0.08
#  2022-02-01      0.08
#  2022-03-01      0.20
#  2022-04-01      0.33
#  2022-05-01      0.77
#  2022-06-01      1.21
#  2022-07-01      1.68)

# %% [markdown]
# ## retrieve CPI

# %%
CPI_df=read_CPI()

plot_ticker_data(CPI_df, fx_size=15, fy_size=8, color_ = 'red')
CPI_df.describe(), CPI_df.head(), CPI_df.tail()
# Out:
# (       MEDCPIM158SFRBCLE
#  count         450.000000
#  mean            2.904248
#  std             1.180348
#  min            -0.286064
#  25%             2.202506
#  50%             2.763044
#  75%             3.435887
#  max             9.130538,
#              MEDCPIM158SFRBCLE
#  DATE
#  1985-01-01           3.074903
#  1985-02-01           5.603398
#  1985-03-01           4.714338
#  1985-04-01           4.493616
#  1985-05-01           3.307093,
#              MEDCPIM158SFRBCLE
#  DATE
#  2022-02-01           6.506399
#  2022-03-01           5.902594
#  2022-04-01           6.527993
#  2022-05-01           7.211770
#  2022-06-01           9.130538)

# %% [markdown]
# ## groupby-month rolling CPI

# %%
CPI_df=read_CPI()
CPI_df,count=groupby_month(CPI_df)
CPI_df.describe(), CPI_df.head(), CPI_df.tail()
# Out:
# (       MEDCPIM158SFRBCLE
#  count         450.000000
#  mean            2.904248
#  std             1.180348
#  min            -0.286064
#  25%             2.202506
#  50%             2.763044
#  75%             3.435887
#  max             9.130538,
#              MEDCPIM158SFRBCLE
#  DATE
#  1985-01-31           3.074903
#  1985-02-28           5.603398
#  1985-03-31           4.714338
#  1985-04-30           4.493616
#  1985-05-31           3.307093,
#              MEDCPIM158SFRBCLE
#  DATE
#  2022-02-28           6.506399
#  2022-03-31           5.902594
#  2022-04-30           6.527993
#  2022-05-31           7.211770
#  2022-06-30           9.130538)

# %%
CPI_df=read_CPI()
#CPI_df.loc[pd.to_datetime('2022-06-01')] = [7.8]
CPI_df, dummy=groupby_month(CPI_df)
plot_ticker_data(CPI_df, fx_size=15, fy_size=8, color_ = 'green')
CPI_df.describe(), CPI_df.head(), CPI_df.tail()
# Out:
# (       MEDCPIM158SFRBCLE
#  count         450.000000
#  mean            2.904248
#  std             1.180348
#  min            -0.286064
#  25%             2.202506
#  50%             2.763044
#  75%             3.435887
#  max             9.130538,
#              MEDCPIM158SFRBCLE
#  DATE
#  1985-01-31           3.074903
#  1985-02-28           5.603398
#  1985-03-31           4.714338
#  1985-04-30           4.493616
#  1985-05-31           3.307093,
#              MEDCPIM158SFRBCLE
#  DATE
#  2022-02-28           6.506399
#  2022-03-31           5.902594
#  2022-04-30           6.527993
#  2022-05-31           7.211770
#  2022-06-30           9.130538)

# %% [markdown]
# ## coor cpi fedrate

# %%
CPI_df.columns,FEDFUNDSRate_df.columns
# Out:
# (Index(['MEDCPIM158SFRBCLE'], dtype='object'),
#  Index(['fedfunds'], dtype='object'))

# %%
hm,ttp,dummy =index_correlation(CPI_df,FEDFUNDSRate_df)

# %%
maxsh = 0
maxcorr = 0.0
for sh in range(0, 3, 3):
    hm=Fed_indexes_corr(FEDFUNDSRate_df, CPI_df, shift__= sh, 
                            bottom_year='1985-1-01',
                            top_year='2027-12-01')
    print('shift:', sh, '   corr:', hm.iloc[0,1])
    if hm.iloc[0,1] > maxcorr: 
        maxcorr = hm.iloc[0,1]
        maxsh = sh
print('shift:', maxsh, '   corr:',maxcorr)
# Out:
# shift: 0    corr: 0.4922787984074044
# shift: 0    corr: 0.4922787984074044

# %% [markdown]
# ## retreive recession

# %%
Recession_df = read_Recession()
Recession_df.describe(),Recession_df.head(n=2), Recession_df.tail(n=2)
# Out:
# (            USREC
#  count  451.000000
#  mean     0.079823
#  std      0.271319
#  min      0.000000
#  25%      0.000000
#  50%      0.000000
#  75%      0.000000
#  max      1.000000,
#              USREC
#  DATE
#  1985-01-01      0
#  1985-02-01      0,
#              USREC
#  DATE
#  2022-06-01      0
#  2022-07-01      0)

# %%
def Recessions_plot(ax, start_date, end_date):
    ticker = 'USREC'
    rd_type = 'fred'
    Recession_df = DataReader(ticker, rd_type, 
                            start = start_date, end = end_date) 

    Recession_df['index']= Recession_df.index
    threshold = 0
    ax.fill_between(Recession_df['index'], 0, 1, where=Recession_df[Recession_df.columns[0]] > threshold,
                    color='green', alpha=0.5, transform=ax.get_xaxis_transform())
    return(1)

# %% [markdown]
# ## Retrieve Brave-Butters-Kelley Cycle Component of GDP

# %% [markdown]
# Earlier this year, a new “big data” activity index was introduced in an Economic Perspectives article.1 This index was constructed from 500 monthly measures of growth in U.S. economic activity and quarterly U.S. real GDP growth. To recap that work, the authors developed what is referred to as a mixed-frequency collapsed dynamic factor model2 that allowed for the estimation of the unobserved monthly evolution of quarterly U.S. real GDP growth based on the variation in a panel of 500 monthly time series. Included in this panel were the coincident, leading, and lagging monthly real activity indicators commonly used to assess the state of the business cycle for the United States. Using this model, the authors then decomposed monthly real GDP growth into three separate components: trend, cycle, and irregular components. The big data activity index represented the cycle component of this decomposition and was shown to have several highly desirable properties, including being 99% accurate in aligning with historical U.S. recessions and expansions as defined by the National Bureau of Economic Research (NBER) since 1960.3

# %%
BBKMCY_df=read_ticker_data(ticker='BBKMCY')
BBKMCY_df.loc[pd.to_datetime('2022-06-01')] = [-1.0]
BBKMCY_df,count=groupby_month(BBKMCY_df)

plot_ticker_data(BBKMCY_df, fx_size=15, fy_size=8, color_ = 'green')
BBKMCY_df.describe(), BBKMCY_df.head(), BBKMCY_df.tail()
# Out:
# (           BBKMCY
#  count  450.000000
#  mean    -0.310894
#  std      3.135826
#  min    -38.771433
#  25%     -0.900554
#  50%      0.013773
#  75%      1.005218
#  max     10.715806,
#                BBKMCY
#  DATE
#  1985-01-31 -0.664751
#  1985-02-28  0.183190
#  1985-03-31  1.142127
#  1985-04-30 -0.195582
#  1985-05-31  0.445028,
#                BBKMCY
#  DATE
#  2022-02-28  0.419364
#  2022-03-31  0.836047
#  2022-04-30 -0.229555
#  2022-05-31 -0.595858
#  2022-06-30 -1.000000)

# %%
maxsh = 0
maxcorr = 0.0
for sh in range(0, 3, 6):

    hm=Fed_indexes_corr(FEDFUNDSRate_df, BBKMCY_df, shift__= sh, 
                            bottom_year='1985-1-01',
                            top_year='2008-12-01')
    print('shift:', sh, '   corr:', hm.iloc[0,1])
    if hm.iloc[0,1] > maxcorr: 
        maxcorr = hm.iloc[0,1]
        maxsh = sh
print('shift:', maxsh, '   corr:',maxcorr)
# Out:
# ERROR! Session/line number was not unique in
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# /var/folders/7s/x40lc7k52vg70w0xtdts0w280000gn/T/ipykernel_10169/244004396.py in <module>
#       5     hm=Fed_indexes_corr(FEDFUNDSRate_df, BBKMCY_df, shift__= sh,
#       6                             bottom_year='1985-1-01',
# ----> 7                             top_year='2008-12-01')
#       8     print('shift:', sh, '   corr:', hm.iloc[0,1])
#       9     if hm.iloc[0,1] > maxcorr:
#
# /var/folders/7s/x40lc7k52vg70w0xtdts0w280000gn/T/ipykernel_10169/4054876031.py in Fed_indexes_corr(Primary_df, Secondary_df, condition, shift__, bottom_year, top_year)
#      11     Primary_df[Secondary_df.columns[0]] = 0
#      12
# ---> 13     Secondary_df = Secondary_df[Primary_df['index'] > bottom_year]
#      14     Primary_df = Primary_df[Primary_df['index'] > bottom_year]
#      15     Secondary_df = Secondary_df[Primary_df['index' ] < top_year]
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2916         # Do we have a (boolean) 1d indexer?
#    2917         if com.is_bool_indexer(key):
# -> 2918             return self._getitem_bool_array(key)
#    2919
#    2920         # We are left with two options: a single key, and a collection of keys,
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    2965         # check_bool_indexer will throw exception if Series key cannot
#    2966         # be reindexed to match DataFrame rows
# -> 2967         key = check_bool_indexer(self.index, key)
#    2968         indexer = key.nonzero()[0]
#    2969         return self._take(indexer, axis=0)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexing.py in check_bool_indexer(ax, key)
#    2484         mask = isna(result._values)
#    2485         if mask.any():
# -> 2486             raise IndexingError('Unalignable boolean Series provided as '
#    2487                                 'indexer (index of the boolean Series and of '
#    2488                                 'the indexed object do not match')
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match
#  database. History logging moved to new session 10023

# %% [markdown]
# ## Retrieve M1 money supply

# %%
M1_df=read_ticker_data(ticker='M1SL',
                       start_date = '1985/1/01',
                        end_date = '2022/07/30')

M1_df.loc[pd.to_datetime('2022-06-01')] = [20640]
M1_df,count=groupby_month(M1_df)
plot_ticker_data(M1_df, fx_size=15, fy_size=8, color_ = 'green')
M1_df.describe(), M1_df.head(), M1_df.tail()
# Out:
# (               M1SL
#  count    450.000000
#  mean    2624.232222
#  std     4166.315088
#  min      557.000000
#  25%     1075.150000
#  50%     1297.500000
#  75%     2474.275000
#  max    20699.300000,
#               M1SL
#  DATE
#  1985-01-31  557.0
#  1985-02-28  563.6
#  1985-03-31  566.6
#  1985-04-30  570.4
#  1985-05-31  575.1,
#                 M1SL
#  DATE
#  2022-02-28  20661.3
#  2022-03-31  20699.3
#  2022-04-30  20615.3
#  2022-05-31  20620.7
#  2022-06-30  20640.0)

# %% [markdown]
# ## Fed rate vs. M1

# %%
maxsh = 0
maxcorr = 0.0
for sh in range(0, 3, 3):
    hm=Fed_indexes_corr(FEDFUNDSRate_df, M1_df, shift__= sh, 
                            bottom_year='1985-1-01',
                            top_year='2019-12-01')
    print('shift:', sh, '   corr:', hm.iloc[0,1])
    if hm.iloc[0,1] > maxcorr: 
        maxcorr = hm.iloc[0,1]
        maxsh = sh
print('shift:', maxsh, '   corr:',maxcorr)
# Out:
# shift: 0    corr: nan
# shift: 0    corr: 0.0

# %%
maxsh = 0
maxcorr = 0.0
for sh in range(0, 3, 3):
    hm=Fed_indexes_corr(FEDFUNDSRate_df, M1_df, shift__= sh, 
                            bottom_year='2008-1-01',
                            top_year='2019-12-01')
    print('shift:', sh, '   corr:', hm.iloc[0,1])
    if hm.iloc[0,1] > maxcorr: 
        maxcorr = hm.iloc[0,1]
        maxsh = sh
print('shift:', maxsh, '   corr:',maxcorr)
# Out:
# shift: 0    corr: nan
# shift: 0    corr: 0.0

# %% [markdown]
# ## BBKMCY_df vs M1

# %%
maxsh = 0
maxcorr = 0.0
for sh in range(0, 3, 3):
    hm=Fed_indexes_corr(BBKMCY_df, M1_df, shift__= sh, 
                            bottom_year='2008-1-01',
                            top_year='2019-12-01')
    print('shift:', sh, '   corr:', hm.iloc[0,1])
    if hm.iloc[0,1] > maxcorr: 
        maxcorr = hm.iloc[0,1]
        maxsh = sh
print('shift:', maxsh, '   corr:',maxcorr)
# Out:
# shift: 0    corr: 0.48526899857950734
# shift: 0    corr: 0.48526899857950734

# %% [markdown]
# ## Retrieve NASDAS composite index IXIC

# %%
IXIC_df=read_ticker_data(ticker='^IXIC', rd_type='yahoo')
#IXIC_df.loc[pd.to_datetime('2022-06-01')] = [-1.0]
IXIC_df,dummy=groupby_month(IXIC_df)
IXIC_df=rolling_12_month(IXIC_df)
IXIC_df =  IXIC_df.iloc[:-1] # drop last month if not edof month
IXIC_df.drop(['High', 'Low','Open', 'Close', 'Volume'], axis=1, inplace=True)
plot_ticker_data(IXIC_df, fx_size=15, fy_size=8, color_ = 'green')

IXIC_df.describe(), IXIC_df.head(), IXIC_df.tail()
# Out:
# (          Adj Close
#  count    450.000000
#  mean    3023.091092
#  std     3215.541907
#  min      260.845456
#  25%      760.928693
#  50%     2071.452342
#  75%     3821.121627
#  max    15814.932896,
#               Adj Close
#  Date
#  1985-01-31  260.845456
#  1985-02-28  285.521052
#  1985-03-31  280.428574
#  1985-04-30  280.895238
#  1985-05-31  287.513636,
#                 Adj Close
#  Date
#  2022-02-28  13898.728413
#  2022-03-31  13623.262950
#  2022-04-30  13394.163037
#  2022-05-31  11829.729539
#  2022-06-30  11418.919085)

# %%
maxsh = 0
maxcorr = 0.0
for sh in range(0, 3, 3):
    hm=Fed_indexes_corr(FEDFUNDSRate_df, IXIC_df, shift__= sh, 
                            bottom_year='1985-1-01',
                            top_year='2022-12-01')
    print('shift:', sh, '   corr:', hm.iloc[0,1])
    if hm.iloc[0,1] > maxcorr: 
        maxcorr = hm.iloc[0,1]
        maxsh = sh
print('shift:', maxsh, '   corr:',maxcorr)
# Out:
# shift: 0    corr: nan
# shift: 0    corr: 0.0

# %%
maxsh = 0
maxcorr = 0.0
for sh in range(0, 37, 5):
    hm=Fed_indexes_corr(FEDFUNDSRate_df, IXIC_df, shift__= sh, 
                            bottom_year='1996-1-01',
                            top_year='2008-12-01')
    print('shift:', sh, '   corr:', hm.iloc[0,1])
    if hm.iloc[0,1] > maxcorr: 
        maxcorr = hm.iloc[0,1]
        maxsh = sh
print('shift:', maxsh, '   corr:',maxcorr)
# Out:
# shift: 0    corr: nan
# shift: 5    corr: nan
# shift: 10    corr: nan
# shift: 15    corr: nan
# shift: 20    corr: nan
# shift: 25    corr: nan
# shift: 30    corr: nan
# shift: 35    corr: nan
# shift: 0    corr: 0.0

# %% [markdown]
# ## M1 vs NASDAQ

# %%
M1_df.describe(), IXIC_df.describe() ,M1_df, IXIC_df,
# Out:
# (               M1SL
#  count    450.000000
#  mean    2624.232222
#  std     4166.315088
#  min      557.000000
#  25%     1075.150000
#  50%     1297.500000
#  75%     2474.275000
#  max    20699.300000,
#            Adj Close
#  count    450.000000
#  mean    3023.091092
#  std     3215.541907
#  min      260.845456
#  25%      760.928693
#  50%     2071.452342
#  75%     3821.121627
#  max    15814.932896,
#                 M1SL      index
#  DATE
#  1985-01-31    557.0 1985-01-31
#  1985-02-28    563.6 1985-02-28
#  1985-03-31    566.6 1985-03-31
#  1985-04-30    570.4 1985-04-30
#  1985-05-31    575.1 1985-05-31
#  1985-06-30    582.3 1985-06-30
#  1985-07-31    589.1 1985-07-31
#  1985-08-31    596.2 1985-08-31
#  1985-09-30    603.3 1985-09-30
#  1985-10-31    607.8 1985-10-31
#  1985-11-30    612.2 1985-11-30
#  1985-12-31    619.8 1985-12-31
#  1986-01-31    621.4 1986-01-31
#  1986-02-28    625.2 1986-02-28
#  1986-03-31    633.5 1986-03-31
#  1986-04-30    641.0 1986-04-30
#  1986-05-31    652.0 1986-05-31
#  1986-06-30    660.6 1986-06-30
#  1986-07-31    670.3 1986-07-31
#  1986-08-31    678.7 1986-08-31
#  1986-09-30    687.4 1986-09-30
#  1986-10-31    694.9 1986-10-31
#  1986-11-30    705.4 1986-11-30
#  1986-12-31    724.7 1986-12-31
#  1987-01-31    730.2 1987-01-31
#  1987-02-28    730.7 1987-02-28
#  1987-03-31    733.8 1987-03-31
#  1987-04-30    743.9 1987-04-30
#  1987-05-31    745.8 1987-05-31
#  1987-06-30    743.2 1987-06-30
#  ...             ...        ...
#  2020-01-31   3993.6 2020-01-31
#  2020-02-29   4002.9 2020-02-29
#  2020-03-31   4261.9 2020-03-31
#  2020-04-30   4779.8 2020-04-30
#  2020-05-31  16232.9 2020-05-31
#  2020-06-30  16563.5 2020-06-30
#  2020-07-31  16763.8 2020-07-31
#  2020-08-31  16896.7 2020-08-31
#  2020-09-30  17161.5 2020-09-30
#  2020-10-31  17365.3 2020-10-31
#  2020-11-30  17626.7 2020-11-30
#  2020-12-31  17834.4 2020-12-31
#  2021-01-31  18107.0 2021-01-31
#  2021-02-28  18367.6 2021-02-28
#  2021-03-31  18641.1 2021-03-31
#  2021-04-30  18927.4 2021-04-30
#  2021-05-31  19259.5 2021-05-31
#  2021-06-30  19319.6 2021-06-30
#  2021-07-31  19497.4 2021-07-31
#  2021-08-31  19746.4 2021-08-31
#  2021-09-30  19898.8 2021-09-30
#  2021-10-31  20063.6 2021-10-31
#  2021-11-30  20279.8 2021-11-30
#  2021-12-31  20430.7 2021-12-31
#  2022-01-31  20585.4 2022-01-31
#  2022-02-28  20661.3 2022-02-28
#  2022-03-31  20699.3 2022-03-31
#  2022-04-30  20615.3 2022-04-30
#  2022-05-31  20620.7 2022-05-31
#  2022-06-30  20640.0 2022-06-30
#
#  [450 rows x 2 columns],
#                 Adj Close      index
#  Date
#  1985-01-31    260.845456 1985-01-31
#  1985-02-28    285.521052 1985-02-28
#  1985-03-31    280.428574 1985-03-31
#  1985-04-30    280.895238 1985-04-30
#  1985-05-31    287.513636 1985-05-31
#  1985-06-30    290.445000 1985-06-30
#  1985-07-31    302.040907 1985-07-31
#  1985-08-31    298.245457 1985-08-31
#  1985-09-30    287.936843 1985-09-30
#  1985-10-31    285.373911 1985-10-31
#  1985-11-30    304.359999 1985-11-30
#  1985-12-31    320.238097 1985-12-31
#  1986-01-31    328.536366 1986-01-31
#  1986-02-28    348.786840 1986-02-28
#  1986-03-31    368.280000 1986-03-31
#  1986-04-30    382.540913 1986-04-30
#  1986-05-31    388.490479 1986-05-31
#  1986-06-30    398.595237 1986-06-30
#  1986-07-31    385.895455 1986-07-31
#  1986-08-31    375.623808 1986-08-31
#  1986-09-30    358.261903 1986-09-30
#  1986-10-31    355.047828 1986-10-31
#  1986-11-30    358.084214 1986-11-30
#  1986-12-31    354.899998 1986-12-31
#  1987-01-31    384.238098 1987-01-31
#  1987-02-28    411.710528 1987-02-28
#  1987-03-31    432.186364 1987-03-31
#  1987-04-30    422.747621 1987-04-30
#  1987-05-31    416.640001 1987-05-31
#  1987-06-30    423.704544 1987-06-30
#  ...                  ...        ...
#  2020-01-31   9233.359980 2020-01-31
#  2020-02-29   9418.850021 2020-02-29
#  2020-03-31   7772.205833 2020-03-31
#  2020-04-30   8292.407180 2020-04-30
#  2020-05-31   9105.655469 2020-05-31
#  2020-06-30   9839.971325 2020-06-30
#  2020-07-31  10499.862704 2020-07-31
#  2020-08-31  11212.290504 2020-08-31
#  2020-09-30  11088.679967 2020-09-30
#  2020-10-31  11435.234109 2020-10-31
#  2020-11-30  11794.461523 2020-11-30
#  2020-12-31  12619.050914 2020-12-31
#  2021-01-31  13186.605777 2021-01-31
#  2021-02-28  13737.403629 2021-02-28
#  2021-03-31  13168.811821 2021-03-31
#  2021-04-30  13900.437965 2021-04-30
#  2021-05-31  13520.229053 2021-05-31
#  2021-06-30  14097.169078 2021-06-30
#  2021-07-31  14639.072870 2021-07-31
#  2021-08-31  14856.517711 2021-08-31
#  2021-09-30  15023.538551 2021-09-30
#  2021-10-31  14879.012323 2021-10-31
#  2021-11-30  15814.932896 2021-11-30
#  2021-12-31  15474.431729 2021-12-31
#  2022-01-31  14531.377490 2022-01-31
#  2022-02-28  13898.728413 2022-02-28
#  2022-03-31  13623.262950 2022-03-31
#  2022-04-30  13394.163037 2022-04-30
#  2022-05-31  11829.729539 2022-05-31
#  2022-06-30  11418.919085 2022-06-30
#
#  [450 rows x 2 columns])

# %%
maxsh = 0
maxcorr = 0.0
 # delete june 
for sh in range(0, 3, 3):
    hm=Fed_indexes_corr(M1_df, IXIC_df, shift__= sh, 
                            bottom_year='200-1-01',
                            top_year='2019-12-01')
    print('shift:', sh, '   corr:', hm.iloc[0,1])
    if hm.iloc[0,1] > maxcorr: 
        maxcorr = hm.iloc[0,1]
        maxsh = sh
print('shift:', maxsh, '   corr:',maxcorr)
# Out:
# shift: 0    corr: 0.9462795733382383
# shift: 0    corr: 0.9462795733382383

# %%
maxsh = 0
maxcorr = 0.0
 # delete june 
for sh in range(0, 3, 3):
    hm=Fed_indexes_corr(M1_df, IXIC_df, shift__= sh, 
                            bottom_year='2006-1-01',
                            top_year='2019-12-01')
    print('shift:', sh, '   corr:', hm.iloc[0,1])
    if hm.iloc[0,1] > maxcorr: 
        maxcorr = hm.iloc[0,1]
        maxsh = sh
print('shift:', maxsh, '   corr:',maxcorr)
# Out:
# shift: 0    corr: 0.9462795733382383
# shift: 0    corr: 0.9462795733382383
